# %% [markdown]
# <a href="https://colab.research.google.com/github/songdh1104/AIPYTHON/blob/main/250502.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# 예시 데이터: 월별 기온
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
temperatures = [5, 7, 12, 18, 22]

plt.plot(months, temperatures) # x축 데이터, y축 데이터 순서로 입력
plt.title('Monthly Temperature Change') # 그래프 제목
plt.xlabel('Month')                 # x축 이름
plt.ylabel('Temperature (C)')       # y축 이름
plt.show()                          # 그래프 보여주기

# 예시 데이터: 키와 몸무게
height = [160, 165, 170, 175, 180]
weight = [55, 60, 68, 72, 78]

plt.scatter(height, weight) # x축 데이터, y축 데이터
plt.title('Height vs Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# 예시 데이터: 과일별 판매량
fruits = ['Apple', 'Banana', 'Orange']
sales = [100, 150, 80]

plt.bar(fruits, sales) # x축 카테고리, y축 값
plt.title('Fruit Sales')
plt.xlabel('Fruit')
plt.ylabel('Quantity Sold')
plt.show()

# 예시 데이터: 학생들의 시험 점수
scores = [65, 72, 75, 78, 80, 82, 85, 88, 90, 91, 93, 95, 98, 100]

plt.hist(scores, bins=5) # 데이터, 구간(bin) 개수 설정
plt.title('Exam Score Distribution')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()
# Matplotlib 예시와 동일한 데이터 사용
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
temperatures = [5, 7, 12, 18, 22]

sns.lineplot(x=months, y=temperatures) # x=, y= 로 명시적으로 지정 가능
plt.title('Monthly Temperature Change (Seaborn)')
plt.xlabel('Month')
plt.ylabel('Temperature (C)')
plt.show()

# Matplotlib 예시와 동일한 데이터 사용
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
temperatures = [5, 7, 12, 18, 22]

sns.lineplot(x=months, y=temperatures) # x=, y= 로 명시적으로 지정 가능
plt.title('Monthly Temperature Change (Seaborn)')
plt.xlabel('Month')
plt.ylabel('Temperature (C)')
plt.show()

# Matplotlib 예시와 동일한 데이터 사용
fruits = ['Apple', 'Banana', 'Orange']
sales = [100, 150, 80]

sns.barplot(x=fruits, y=sales)
plt.title('Fruit Sales (Seaborn)')
plt.xlabel('Fruit')
plt.ylabel('Quantity Sold')
plt.show()


# Matplotlib 예시와 동일한 데이터 사용
scores = [65, 72, 75, 78, 80, 82, 85, 88, 90, 91, 93, 95, 98, 100]

sns.histplot(scores, bins=5)
plt.title('Exam Score Distribution (Seaborn)')
plt.xlabel('Score')
plt.ylabel('Frequency') # Seaborn은 보통 빈도(Frequency)로 표시
plt.show()

# %%
! sudu apt-get install -y fonts-nanum
# Out:
# /bin/bash: line 1: sodu: command not found

# %%
import matpliotlib as plt

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
plt.plot(year, kor)
plt.show()
#선그래프
#그래프 출력

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

year = ['2006', '2009', '2012', '2015', '2018']
kor = [547, 546, 554, 524, 526]
#막대그래프
plt.show()

# %%
import matplotlib.pyplot as plt

kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
#산점도그래프
plt.show()

# %%
import matplotlib.pyplot as plt

score = [547,546,554,524,526,474,487,481,470,478,523,529,536,532,527]
plt.hist(score)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2009, 2012, 2015]
y = [529, 536, 532]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2006, 2009, 2012, 2015]
y = [523, 529, 536, 532]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['a', 'b', 'c']
y = [7, 5, 4]
plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
plt.plot(year, kor)
plt.show()

# %%
import matplotlib.pyplot as plt  # Import pyplot for plotting functions
import seaborn as sns

plt.figure(figsize=(10, 5))
year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
# year kor 그래프
sns.lineplot(x=year, y=kor, color ='r', linestyle = ':', label = 'kor')
# year usa 그래프
sns.lineplot(x=year, y=usa, color ='b', label = 'usa')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt  # Import pyplot for plotting functions
import seaborn as sns

plt.figure(figsize=(10, 5))
year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
jpn = [523, 529, 536, 532, 527]
sns.lineplot(x=year, y=kor, color ='r', linestyle = ':', label = 'kor')
# year usa 그래프
sns.lineplot(x=year, y=usa, color ='b', label = 'usa')
sns.lineplot(x=year, y=jpn, color ='g', label = 'jpn')
plt.legend()
plt.ylim(400, 600)  # y축 범위 설정
# 그래프에 범례를 추가
# 그래프 제목을 'Mathematics performance'로 설정합니다.
plt.xlabel('year')
plt.ylabel('score')
for i in range(len(kor)):
  plt.annotate([i],xy=(year[i],kor[i]),xytext=(5,-10),textcoords='offset points')
  i += 1
plt.show()

# %%
import matplotlib.pyplot as plt

notebook = {'g○○':150,'t○○':100,'m○○':160,'s○○':170}

plt.figure(figsize=(5,3))
# 막대 그래프의 x축은 딕셔너리의 키(제품이름)를 사용하고, 막대 그래프의 Y축은 딕셔너리의 값(가격)을 사용하고, 각 막대의 너비를 0.7 단위로 설정
plt.xlabel('product name')
plt.ylabel('price')
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2000, 2005, 2010, 2015, 2020]
single_person = [15.5, 20.0, 23.9, 27.2, 31.7]
baby_born = [640089, 438707, 470171, 438420, 272337]

plt.figure(figsize=(5,3))
 # 1인 가구 비율(single_person)과 출생아 수(baby_born) 사이의 관계를 나타내는 산점도를 그립니다.
for i in range(len(year)):
  plt.annotate(year[i],xy=(single_person[i], baby_born[i]),xytext=(5,-10),textcoords='offset points') #각 연도에 해당하는 데이터 지점 옆에 해당 연도를 표시하는 주석을 추가
plt.xlim(14,35)
plt.ylim(230000,700000)
plt.xlabel('single-person household ratio')
plt.ylabel('the number of babies born')
plt.show()

# %%
import matplotlib.pyplot as plt
import random

x = [random.randint(1,100) for i in range(1000)]

plt.figure(figsize=(5,3))
# 데이터 배열 x를 20개의 구간으로 나누고 50% 투명도로 표시하는 빈도 분포 그래프를 생성
plt.ylabel('frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

exercise ={'climbing':0,'soccer':0,'swimming':0,'tennis':0}

print('좋아하는 운동을 입력하세요.')
print('복수 개의 운동을 입력하려면 콤마로 구분하세요.')

while True:
  s = input('climbing,soccer,swimming,tennis,종료: ')
  if s=='종료':
    break
  for a in s.split(','):
    if a in exercise:
      # 해당 운동의 카운트를 1 증가시키는 연산
    else:
      print(f'{a}는 등록되지 않은 운동입니다.')

plt.figure(figsize=(5.5,3))
plt.bar(exercise.keys(), exercise.values(), color='g', width=0.6)
#plt.xticks(rotation='vertical')
plt.xlabel('exercise')
plt.ylabel('frequency')
plt.show()

# %%
#다음 데이터를 이용하여 1년 동안의 월별 평균 강수량을 꺾은선 그래프로 그려보세요.
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
rain = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]
# 그래프 제목과 x, y축 레이블을 추가하세요.

import matplotlib as plt
import seaborn as sns

sns.lineplot(x=month, y=rain)
plt.title('mean rain')
plt.xlabel('Month')
plt.xlabel('rain(mm)')
plt.figure(figsize=(20,5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-8f47e9e8e945> in <cell line: 0>()
#       8
#       9 sns.lineplot(x=month, y=rain)
# ---> 10 plt.title('mean rain')
#      11 plt.xlabel('Month')
#      12 plt.xlabel('rain(mm)')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     216         if name in props:
#     217             return props[name].__get__(instance)
# --> 218         raise AttributeError(
#     219             f"module {cls.__module__!r} has no attribute {name!r}")
#     220
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
import matplotlib.pyplot as plt  # Import pyplot for plotting functions
import seaborn as sns

plt.figure(figsize=(10, 5))  # Set figure size before creating the plot
sns.lineplot(x=month, y=rain, color ='r', linestyle = ':', label = 'rain')
plt.legend()
plt.title('mean rain')
plt.xlabel('Month')
plt.ylabel('rain(mm)')  # Use plt.ylabel for the y-axis label
for i in range(len(name)):
  plt.annotate(name[i],xy=(x[i],y[i]),xytext=(5,-10),textcoords='offset points')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-153bda9e126e> in <cell line: 0>()
#       8 plt.xlabel('Month')
#       9 plt.ylabel('rain(mm)')  # Use plt.ylabel for the y-axis label
# ---> 10 for i in range(len(name)):
#      11   plt.annotate(name[i],xy=(x[i],y[i]),xytext=(5,-10),textcoords='offset points')
#      12 plt.show()
#
# NameError: name 'name' is not defined
